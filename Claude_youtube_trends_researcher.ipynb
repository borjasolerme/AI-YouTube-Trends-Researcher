# %% [markdown]
# <a href="https://colab.research.google.com/github/borjasolerme/AI-YouTube-Trends-Researcher/blob/main/Claude_youtube_trends_researcher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install youtube-search-python
# !pip install anthropic
# !pip install requests
# !pip install datetime
# !pip install python-docx

# %%
import asyncio
import re
import requests
from youtubesearchpython import CustomSearch, VideosSearch
import anthropic
import nest_asyncio
import time
import logging
from datetime import datetime, timedelta
from google.colab import files
from docx import Document
from collections import defaultdict

nest_asyncio.apply()  # Apply nest_asyncio to allow nested event loops

ANTHROPIC_API_KEY = "YOUR_API_KEY_HERE"  # Replace with your Anthropic API key

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

def remove_first_line(test_string):
    # Remove the first line of the response if it starts with "Here" and ends with a colon
    if test_string.startswith("Here") and test_string.split("\n")[0].strip().endswith(":"):
        return re.sub(r'^.*\n', '', test_string, count=1)
    return test_string

def generate_text(prompt, model="claude-3-haiku-20240307", max_tokens=2000, temperature=0.7):
    # Generate text using the Anthropic API
    headers = {
        "x-api-key": ANTHROPIC_API_KEY,
        "anthropic-version": "2023-06-01",
        "content-type": "application/json"
    }
    data = {
        "model": model,
        "max_tokens": max_tokens,
        "temperature": temperature,
        "system": "You are a world-class researcher. Analyze the given information and generate a well-structured report.",
        "messages": [{"role": "user", "content": prompt}],
    }
    try:
        response = requests.post("https://api.anthropic.com/v1/messages", headers=headers, json=data)
        response.raise_for_status()
        response_text = response.json()['content'][0]['text']
        return remove_first_line(response_text.strip())
    except requests.exceptions.RequestException as e:
        logger.error(f"Error generating text: {str(e)}")
        return None

def get_top_topics(trending_videos, count=30):
    topic_count = defaultdict(lambda: {'count': 0, 'views': 0})

    for video in trending_videos:
        if 'descriptionSnippet' in video and video['descriptionSnippet']:
            description = video['descriptionSnippet'][0]['text']
            words = re.findall(r'\w+', description)
            for word in words:
                topic_count[word]['count'] += 1
                topic_count[word]['views'] += int(video['viewCount']['text'].replace(',', ''))

    sorted_topics = sorted(topic_count.items(), key=lambda x: x[1]['count'], reverse=True)
    return [(topic, data['count'], data['views']) for topic, data in sorted_topics[:count]]

def rank_video_trends(trending_videos):
    titles = [video['title'] for video in trending_videos]
    views = [int(video['viewCount']['text'].replace(',', '').replace(' views', '')) if video.get('viewCount') and video['viewCount'].get('text') else 0 for video in trending_videos]
    prompt = f"""
    I am going to give you a list of videos from Youtube along with their view counts. After you will need to analyze them and rank the videos by topics.

    <examples>
    {format_examples_with_views(titles, views)}
    </examples>

    <instructions>
    Analyze the video titles and view counts, then perform the following tasks:
    - Identify the main topic or theme of each video based on the video titles.
    - Group the videos by their identified topics.
    - Use the most relevant keywords or phrases from the video titles to name each topic.
    - Rank the grouped topics from most repeated to least repeated.
    - Include the total view count for each topic.
    - Give me the output directly without additional comments like in the <output_format> tags
    </instructions>

    <output_format>
    Trends:
    1. [Topic 1]: [Count], [Total Views]
    - [Video Title 1] ([View Count 1])
    - [Video Title 2] ([View Count 2])
    ...
    2. [Topic 2]: [Count], [Total Views]
    - [Video Title 1] ([View Count 1])
    - [Video Title 2] ([View Count 2])
    ...
    ...
    </output_format>

    <prompt>
    Perform the analysis and provide the output in the specified format.
    </prompt>

    Go step by step. Take your time and consider each step carefully to develop the best possible answer.
    """

    ranked_trends = generate_text(prompt)
    return ranked_trends

def generate_mini_report(topic, trending_videos, ranked_trends):
    titles = [video['title'] for video in trending_videos]
    views = [video['viewCount']['text'] for video in trending_videos]

    prompt = f"""
    I am going to give you a list of videos from Youtube and ranked trends from those videos. After you will need to analyze them and generate a report.

    <examples>
    {format_examples_with_views(titles, views)}
    </examples>

    <ranked_trends>
    {ranked_trends}
    </ranked_trends>

    <context>
    Analyze the trending videos and ranked video trends to identify the key trends and insights related to the topic '{topic}'. Generate a report similar to McKinsey and Boston Consulting Group reports.
    </context>

    <instructions>
    - Summarize the main trends and patterns observed in the trending videos and ranked video trends.
    - Highlight the videos with the highest view counts and discuss their impact on the overall trends.
    - Provide insights on how to benefit from the observed trends and create alternative content following the successful patterns.
    - Include actionable recommendations based on the analysis, focusing on leveraging the most viewed videos and their characteristics.
    - Give me the output directly without additional comments like in the <output_format> tags
    </instructions>

    <prompt>
    Generate a comprehensive and data-driven report on the top trends related to the given topic based on the trending YouTube videos and ranked video trends.
    </prompt>

    <output_format>
    Title page
    Table of Contents
    Abstract
    Key findings
    Trends rising
    Opportunities for content creation
    Topics to avoid
    Conclusion/recommendations
    </output_format>

    Go step by step. Take your time and consider each step carefully to develop the best possible answer.
    """

    mini_report = generate_text(prompt)
    return mini_report

async def generate_video_ideas(topic, examples, views, mini_report, num_ideas=5):
    prompt = f"""
    I am going to give you a list of videos from Youtube and a report I have generated. After you will need to give me new video ideas to create.

    <examples>
    {format_examples_with_views(examples, views)}
    </examples>

    <mini_report>
    {mini_report}
    </mini_report>

    <context>
    Use the insights from the trending videos, especially the ones with the highest view counts, and the mini report to inspire new video ideas that are likely to perform well and attract a similar audience.
    </context>

    <instructions>
    - Generate {num_ideas} distinct video ideas that are similar in style and format to the provided examples.
    - Each idea should be creative, engaging, and closely related to the topic and the trending videos.
    - Provide a title for each video idea, following the patterns observed in the examples.
    - Give me the output directly without additional comments like in the <output_format> tags
    </instructions>

    <prompt>
    Generate {num_ideas} video ideas related to the given topic based on the trending YouTube videos and the mini report.
    </prompt>

    <output_format>
    1. [Video title]
    2. [Video title]
    3. [Video title]
    ...
    ...
    </output_format>

    Go step by step. Take your time and consider each step carefully to develop the best possible answer.
    """

    video_ideas = generate_text(prompt)
    if video_ideas:
        video_ideas = video_ideas.split("\n")
        return [idea.strip() for idea in video_ideas if idea.strip()]
    else:
        return []

def format_examples_with_views(examples, views):
    formatted_examples = ""
    for example, view_count in zip(examples, views):
        formatted_examples += f"- {example} ({view_count} views)\n"
    return formatted_examples

def generate_document_content(mini_report, video_ideas, trending_videos):
    document = "Mini Report:\n"
    document += mini_report + "\n\n"

    document += "Most Viewed Trending Videos:\n"
    sorted_videos = sorted(trending_videos, key=lambda x: int(x['viewCount']['text'].replace(',', '').replace(' views', '')) if x.get('viewCount') and x['viewCount'].get('text') else 0, reverse=True)
    for video in sorted_videos[:5]:
        document += f"- {video['title']} ({video['viewCount']['text']} views) - {video['link']}\n"
    document += "\n"

    document += "Video Ideas (Inspired by Trending Videos):\n"
    for i, idea in enumerate(video_ideas, start=1):
        document += f"{i}. {idea}\n"
    document += "\n"

    document += "All Trending YouTube Videos:\n"
    for video in trending_videos:
        document += f"- {video['title']} ({video['viewCount']['text']} views) - {video['link']}\n"

    return document

async def main():
    topic = input("Enter a topic to generate video ideas for: ")
    num_ideas = int(input("Enter the number of video ideas to generate: "))

    # Perform the search without date range filter
    videosSearch = VideosSearch(topic, limit=40)
    trending_videos = videosSearch.result()['result']

    ranked_trends = rank_video_trends(trending_videos)
    print("\nRanked Video Trends:")
    print(ranked_trends)

    mini_report = generate_mini_report(topic, trending_videos, ranked_trends)
    video_ideas = await generate_video_ideas(topic, [video['title'] for video in trending_videos], [video['viewCount']['text'] for video in trending_videos], mini_report, num_ideas)

    document_content = generate_document_content(mini_report, video_ideas, trending_videos)

    print("\nMini Report:")
    print(mini_report)

    print("\nVideo Ideas:")
    for idea in video_ideas:
        print(idea)

    print("\nTrending YouTube Videos:")
    for video in trending_videos:
        print(f"- {video['title']} ({video['viewCount']['text']} views) - {video['link']}")

    # Generate a unique filename based on the topic and current timestamp
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    filename = f"{topic}_{timestamp}.docx"

    # Create a new Word document
    doc = Document()

    # Add the document content to the Word document
    doc.add_paragraph(document_content)

    # Save the Word document
    doc.save(filename)

    print(f"\nDocument saved as: {filename}")

    files.download(filename)

if __name__ == "__main__":
    asyncio.get_event_loop().run_until_complete(main())
# Out:
# Enter a topic to generate video ideas for: formula 1
# Enter the number of video ideas to generate: 10
#
# Ranked Video Trends:
# Trends:
# 1. Formula 1 Race Highlights: 5, 19,966,659 views
# - Race Highlights | 2024 Japanese Grand Prix (5,420,016 views)
# - Race Highlights | 2024 Australian Grand Prix (8,577,670 views)
# - Race Highlights | 2024 Saudi Arabian Grand Prix (5,968,303 views)
# - Qualifying Highlights | 2024 Japanese Grand Prix (3,419,964 views)
# - Qualifying Highlights | 2024 Saudi Arabian Grand Prix (4,080,052 views)
#
# 2. Formula 1 News and Analysis: 6, 1,628,789 views
# - Seven things the Japanese GP revealed about F1 2024 (475,859 views)
# - The brutal cost of Williams's shocking F1 crash streak (344,307 views)
# - HUGE TENSION At Mercedes After Hamilton's FURIOUS MESSAGE! (64,208 views)
# - Aston Martin JUST DESTROYED Stroll with SHOCKING STATEMENT! (54,003 views)
# - Audi busca a Checo y Sainz pero Red Bull le cierra la puerta | ¡Ojo! Mercado de pilotos se mueve (40,179 views)
# - WHY 2026 is a critical year for F1 | Sky Sports F1 Podcast (63,072 views)
#
# 3. Formula 1 Highlights and Reactions: 5, 3,087,166 views
# - Tsunoda Scores Points On Home Soil And The Best Team Radio | 2024 Japanese Grand Prix | Paramount+ (697,269 views)
# - Ricciardo & Albon Lap One Drama! | The Top 10 Onboards | 2024 Japanese Grand Prix | Qatar Airways (151,313 views)
# - Drivers' Reaction After the Race | 2024 Japanese Grand Prix (756,968 views)
# - LIVE: Japanese Grand Prix Post-Race Show (351,651 views)
# - Japanese GP 2024 | Highlights | Formula 1 Comedy (49,048 views)
#
# 4. Formula 1 Collections and Interviews: 2, 120,389 views
# - Formula 1 World Champion Jody Scheckter gives me a tour of his F1 car collection! | RM Sotheby's (120,389 views)
#
# 5. Formula 1 Sim Racing: 3, 348,308 views
# - Qualifying I F1 Sim Racing World Championship 2023/2024 I Round 2 & 3 I Jeddah & Spielberg (348,308 views)
# - Race I F1 Sim Racing World Championship 2023/2024 I Round 2 & 3 I Jeddah & Spielberg (0 views)
#
# 6. Formula 1 Speculation and Rumors: 3, 119,951 views
# - Is Daniel Ricciardo done in F1 after Suzuka crash? (109,986 views)
# - Red Bull suspicions raised as Christian Horner 'holds talks without Helmut Marko' (2,362 views)
# - Proved he's a Formula 1 driver😏 #movie #series (12,544,337 views)
#
# 7. Formula 1 Regulations: 1, 81,592 views
# - The 2026 Formula 1 Regulations are "slower than Formula 2", apparently. (81,592 views)
#
# Mini Report:
# Title page
# Formula 1 Content Trends: Insights and Opportunities
#
# Table of Contents
# 1. Abstract
# 2. Key Findings
# 3. Trends Rising
#    3.1. Formula 1 Race Highlights
#    3.2. Formula 1 News and Analysis
#    3.3. Formula 1 Highlights and Reactions
#    3.4. Formula 1 Collections and Interviews
#    3.5. Formula 1 Sim Racing
#    3.6. Formula 1 Speculation and Rumors
#    3.7. Formula 1 Regulations
# 4. Opportunities for Content Creation
# 5. Topics to Avoid
# 6. Conclusion and Recommendations
#
# Abstract
# This report provides a comprehensive analysis of the top trends in Formula 1 (F1) content on YouTube, based on the trending videos and ranked video trends provided. The insights gleaned from this analysis offer valuable opportunities for content creators and stakeholders to capitalize on the growing interest in F1 content and engage with the audience effectively.
#
# Key Findings
# 1. Formula 1 Race Highlights are the most viewed content, accounting for over 19.9 million views across 5 videos.
# 2. Formula 1 News and Analysis videos are also highly popular, with 6 videos generating over 1.6 million views.
# 3. Formula 1 Highlights and Reactions content, including team radio and onboard footage, have amassed over 3 million views.
# 4. Specialized content, such as Formula 1 Collections and Interviews, as well as Formula 1 Sim Racing, have garnered significant interest.
# 5. Formula 1 Speculation and Rumors, and Formula 1 Regulations-related content, while not as dominant, still attract a sizable audience.
#
# Trends Rising
# 1. Formula 1 Race Highlights:
#    - The top 5 videos in this category have collectively generated over 19.9 million views, highlighting the strong demand for comprehensive race highlights.
#    - These videos provide viewers with a concise and engaging recap of the key moments from each Grand Prix, catering to the needs of fans who may have missed the live action.
#
# 2. Formula 1 News and Analysis:
#    - This category covers a range of topics, from team and driver developments to technical and regulatory changes.
#    - The 6 videos in this trend have accumulated over 1.6 million views, demonstrating the audience's appetite for in-depth analysis and insights into the sport.
#
# 3. Formula 1 Highlights and Reactions:
#    - This trend encompasses content that offers a more intimate and behind-the-scenes look at the sport, such as team radio, onboard footage, and driver reactions.
#    - The 5 videos in this category have generated over 3 million views, highlighting the fans' desire for a deeper connection with the drivers and teams.
#
# 4. Formula 1 Collections and Interviews:
#    - While this category has only 2 videos, they have generated a significant 120,389 views, suggesting a niche interest in content that showcases the sport's history and personalities.
#
# 5. Formula 1 Sim Racing:
#    - The 3 videos in this trend have garnered 348,308 views, indicating a growing interest in the virtual side of the sport and the competitive sim racing scene.
#
# 6. Formula 1 Speculation and Rumors:
#    - This category covers a range of topics, from driver market rumors to controversies and speculation, which have generated over 119,951 views.
#    - While not as dominant as the other trends, this content still attracts a sizable audience, highlighting the fans' interest in the behind-the-scenes narratives of the sport.
#
# 7. Formula 1 Regulations:
#    - The single video in this trend, discussing the 2026 F1 regulations, has generated 81,592 views, suggesting a niche interest in the technical and regulatory aspects of the sport.
#
# Opportunities for Content Creation
# 1. Expand on the successful Formula 1 Race Highlights and Reactions content, providing more in-depth and engaging coverage of the key moments from each Grand Prix.
# 2. Leverage the popularity of Formula 1 News and Analysis by creating content that offers unique insights, predictions, and discussions around the sport's latest developments.
# 3. Explore the opportunity to create more Formula 1 Collections and Interviews, showcasing the rich history and personalities of the sport.
# 4. Capitalize on the growing interest in Formula 1 Sim Racing by producing content that highlights the competitive scene, featuring interviews with top sim racers and insights into the virtual world of F1.
# 5. Consider creating content that addresses the audience's interest in Formula 1 Speculation and Rumors, but maintain a balanced and responsible approach to ensure the content is informative and not sensationalized.
#
# Topics to Avoid
# 1. Avoid producing content that is solely focused on Formula 1 Regulations, as the data suggests a relatively niche interest in this topic.
# 2. Be cautious when creating content that delves too deeply into unsubstantiated Formula 1 Speculation and Rumors, as this may risk alienating the audience or spreading misinformation.
#
# Conclusion and Recommendations
# The analysis of the trending YouTube videos and ranked video trends related to Formula 1 has revealed several key insights and opportunities for content creators and stakeholders. The dominant trends, such as Formula 1 Race Highlights, News and Analysis, and Highlights and Reactions, offer the greatest potential for engaging and growing the audience. By leveraging these successful content formats and expanding on the audience's interests, content creators can capitalize on the growing demand for high-quality Formula 1 content. Additionally, exploring niche opportunities, such as Formula 1 Collections and Interviews, as well as Sim Racing, can help diversify the content offering and cater to specific audience segments. By carefully navigating the trends and opportunities identified in this report, content creators can position themselves for success in the dynamic and ever-evolving Formula 1 content landscape.
#
# Video Ideas:
# 1. Exclusive Interview: Lewis Hamilton Reflects on His Formula 1 Legacy
# 2. Untold Stories: A Rare Glimpse into the Lives of Formula 1 Drivers
# 3. The Rise of Lando Norris: A Young Star's Journey to the Top
# 4. Formula 1 Pit Stop Challenge: Can You Beat the Fastest Crews?
# 5. The Secrets Behind the Fastest Laps: An In-Depth Analysis
# 6. Formula 1 Rivalry Renewed: Verstappen vs. Leclerc in 2025
# 7. Pushing the Boundaries: How Formula 1 Cars Will Evolve in 2027
# 8. Esports Showdown: Top Formula 1 Sim Racers Compete for Glory
# 9. The Controversial Decisions That Shaped the 2024 Season
# 10. Formula 1 Legends Revisited: A Tour of Iconic Race-Winning Cars
#
# Trending YouTube Videos:
# - Qualifying I F1 Sim Racing World Championship 2023/2024 I Round 2 & 3 I Jeddah & Spielberg (348,308 views views) - https://www.youtube.com/watch?v=5G6R7uFRXaw
# - Tsunoda Scores Points On Home Soil And The Best Team Radio | 2024 Japanese Grand Prix | Paramount+ (697,269 views views) - https://www.youtube.com/watch?v=39PmaDID9vo
# - Race Highlights | 2024 Japanese Grand Prix (5,420,016 views views) - https://www.youtube.com/watch?v=Z3-IulIyBtU
# - Formula 1 World Champion Jody Scheckter gives me a tour of his F1 car collection! | RM Sotheby's (120,389 views views) - https://www.youtube.com/watch?v=fgJEWzp9t-M
# - Ricciardo & Albon Lap One Drama! | The Top 10 Onboards | 2024 Japanese Grand Prix | Qatar Airways (151,313 views views) - https://www.youtube.com/watch?v=fXs2Q7lkYdg
# - The 2026 Formula 1 Regulations are "slower than Formula 2", apparently. (81,592 views views) - https://www.youtube.com/watch?v=VWb9JgMBxkI
# - Proved he's a Formula 1 driver😏 #movie #series (12,544,337 views views) - https://www.youtube.com/watch?v=R937gc9t3tA
# - Is Daniel Ricciardo done in F1 after Suzuka crash? (109,986 views views) - https://www.youtube.com/watch?v=4hqXGemKFIA
# - Race I F1 Sim Racing World Championship 2023/2024 I Round 2 & 3 I Jeddah & Spielberg (None views) - https://www.youtube.com/watch?v=-3c7IZnluww
# - Drivers' Reaction After the Race | 2024 Japanese Grand Prix (756,968 views views) - https://www.youtube.com/watch?v=vpwH20aRHqE
# - Race Highlights | 2024 Australian Grand Prix (8,577,670 views views) - https://www.youtube.com/watch?v=9z8sEadieXA
# - Qualifying Highlights | 2024 Japanese Grand Prix (3,419,964 views views) - https://www.youtube.com/watch?v=LYmJAeFnSQ4
# - Japanese GP 2024 | Highlights | Formula 1 Comedy (49,048 views views) - https://www.youtube.com/watch?v=5Imrg30sv_s
# - Seven things the Japanese GP revealed about F1 2024 (475,859 views views) - https://www.youtube.com/watch?v=ffnXYkOm1BI
# - The brutal cost of Williams’s shocking F1 crash streak (344,307 views views) - https://www.youtube.com/watch?v=7FjJ8U9z7cE
# - HUGE TENSION At Mercedes After Hamilton's FURIOUS MESSAGE! (64,208 views views) - https://www.youtube.com/watch?v=emztjvTxfTM
# - Aston Martin JUST DESTROYED Stroll with SHOCKING STATEMENT! (54,003 views views) - https://www.youtube.com/watch?v=OvTxjQIz2qQ
# - Audi busca a Checo y Sainz  pero Red Bull le cierra la puerta  | ¡Ojo! Mercado de pilotos se mueve (40,179 views views) - https://www.youtube.com/watch?v=LTcmPHegvvU
# - WHY 2026 is a critical year for F1 | Sky Sports F1 Podcast (63,072 views views) - https://www.youtube.com/watch?v=PoenATE3lio
# - FP2 Highlights | 2024 Australian Grand Prix (1,885,806 views views) - https://www.youtube.com/watch?v=kP9pMgYBtOY
# - LIVE: Japanese Grand Prix Post-Race Show (351,651 views views) - https://www.youtube.com/watch?v=KaATSFDMBbo
# - FP1 Highlights | 2024 Japanese Grand Prix (1,964,746 views views) - https://www.youtube.com/watch?v=6Xr2vAI4dXs
# - FP2 Highlights | 2024 Japanese Grand Prix (1,557,280 views views) - https://www.youtube.com/watch?v=LZ9opUn8Oc0
# - Qualifying Highlights | 2024 Saudi Arabian Grand Prix (4,080,052 views views) - https://www.youtube.com/watch?v=mquz3QK0SNY
# - Red Bull suspicions raised as Christian Horner 'holds talks without Helmut Marko' (2,362 views views) - https://www.youtube.com/watch?v=LJeFY6eBkfo
# - Race Highlights | 2024 Saudi Arabian Grand Prix (5,968,303 views views) - https://www.youtube.com/watch?v=OJ56MAGFPGM
#
# Document saved as: formula 1_20240410_161725.docx
